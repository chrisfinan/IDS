# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisfinan/IDS/blob/main/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chris Finan
#
#
# > 9/21/23
#
# > Project 2

# %% [markdown]
# Description:
#
# > In this assignment, I will be analyzing two data sets: "US Arrests" and "Child Mortality Rates"

# %% [markdown]
# #**Problem 1**
#
#
# > I will be analyzing the US Arrests statistics per 100,000 residents for assault and murder in each of the 50 states. I will be addressing missing values and smoothing out the data, as well as making graphs to visualize the data.

# %% [markdown]
# ##Excel:

# %% [markdown]
# A. Address all the missing values.
#
# > There was only one missing value in the data set in the "Assault" column, so I replaced it with the average. Assault is the middle number and I rounded it up to match all of the other values in that column as whole numbers
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. Look for outliers and smooth noisy data, if any.
#
#
# > North Dakota: Murders: 0.8 / This would really be the only outlier in the data set, but most of the numbers vary heavily up to 17.4 in this column. I am not going to adjust this value in the data set.

# %% [markdown]
# C. Plot Murder rates for all 50 states
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# D. Plot histogram of assaults
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# E. Plot Murder rate vs. Assault rate.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# F. Prepare the dataset to establish a relation between an urban population category and a crime type.
#
#
#
# > As you can see on the right side, that is my key fo determining which bin the UrbanPop of each state goes into.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SQL:

# %% [markdown]
# A. Import the original CSV file into SQL and create the table USArrests.
#
#
# > I used the CSV to SQL converter linked on Canvas. This is what my initial insert looks like.
#
# ![HW2_SQL_TABLE1.PNG](data:image/png;base64,...)

# %% [markdown]
# B. Use SQL (https://www.programiz.com/sql/online-compiler/Links to an external site.) to replace all missing values in a column by the average.
#
#
# > Here I used this SQL command to replace the only missing value (in Assault) with its average.
#
#
#
# ![HW2_SQL_B.PNG](data:image/png;base64,...)

# %% [markdown]
# C. Find min, max, mean, and variance of all numeric attributes in SQL.
#
#
#
# > These values are found in their respective order using SQL commands below.
#
#
#
#
#
# ![HW2_SQL_MIN.PNG](data:image/png;base64,...)![HW2_SQL_MAX.PNG](data:image/png;base64,...)![HW2_SQL_AVG.PNG](data:image/png;base64,...)![HW2_SQL_VAR.PNG](data:image/png;base64,...)

# %% [markdown]
# D. Use SQL to answer the following questions:<br>
# -- Which state has the maximum murder rate?<br>
#
#
# > Georgia has the maximum murder rate of 17.4. This can be seen above where the SQL command "select max(murder) from US_Arrests;" is used.

# %% [markdown]
# -- List of states in ascending order of urban population percentages.<br>
#
#
# > This is the SQL syntax for ordering the states by ascending order of UrbanPop. The rest of the list is cut off from the screen shot.
#
#
#
# ![HW2_SQL_upAsc.PNG](data:image/png;base64,...)

# %% [markdown]
# -- How many states have higher murder rates than Arizona? List those states.
#
#
# > To find this, I decided to display the states and murder rates and order them in descending order. This way I can count the states that have higher murder rates than Arizona. There are 21 states with a higher murder rate than Arizona. You can see this in the SQL screenshot below. I have listed all of the states with a higher murder rate.
#
#
# ![HW2_SQL_AZ1.PNG](data:image/png;base64,...)![HW2_SQL_AZ2.PNG](data:image/png;base64,...)![HW2_SQL_AZ3.PNG](data:image/png;base64,...)

# %% [markdown]
# Conclusion:
#
# > There is no overall conclusion for problem 1. Please see the individual labeled questions/sections. There are 2 sections to Problem 1. There is an Excel Section and a SQL section. Excel has numbers A-F and SQL has A-D. Each individual letter has its own answer to it. I explained the ones that were necessary to be explained. I have included all the SQL screenshots in for problem one under their respective sections. The Excel csv files will be included in the HW2 GitHub folder.

# %% [markdown]
# #**Problem 2**
#
# > In this problem, I will be analyzing the child mortality rates. I will be filling in the missing data as well as finding relationships between different parts of the data.

# %% [markdown]
# ##Excel

# %% [markdown]
# A. Address all the missing values using the techniques at your disposal.
#
#
# > There were quite a few missing values in each column, so I have attached the whole table from Excel below. I calculated the average of each column and inserted those values into their respective missing spots in each column. I also rounded each new value to 1 decimal place to fit in with the rest of the values.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. Prepare the dataset to establish the following relations (graphs in Excel):<br>
# --Under-ﬁve mortality rate and neonatal mortality rate.<br>
#
#
# > A scatter plot best shows the correlation between two quantitative variables like these mortality rates.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# --Infant mortality rate and neonatal mortality rate.<br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# --Year and infant mortality rate.
#
#
# > This graph shows that the neonatal mortality rate has dropped consistently and significantly over the time period.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##SQL

# %% [markdown]
# A. Import the original data set into SQL (see problem 1).
#
#
# > Here is the beginning of all of the insert statements for the problem 2 table.
#
#
# ![HW2_SQL_TBL2.PNG](data:image/png;base64,...)

# %% [markdown]
# B. Use SQL to fill in the missing values in each column using the medians.
#
#
# > I filled in each of the missing values with the averages in their respective columns using the update command in SQL
#
#
#
# ![HW2_SQL_2B.PNG](data:image/png;base64,...)

# %% [markdown]
# Answer the following queries in SQL: <br>
# -- Display the entire table.
#
#
# > To display the entire table, I would simply use the select * (meaning all) command in SQL. This is shown in the screenshot below.
#
# ![HW2_SQL_display1.PNG](data:image/png;base64,...)

# %% [markdown]
# -- Which years have the lowest and highest infant mortality years, respectively?
#
#
# > The lowest year was 2006 with 30.5 and the highest year was 1990 with 64.8. The SQL calculations of min and max are shown below.
#
# ![HW2_SQL_minmaxinfant.PNG](data:image/png;base64,...)

# %% [markdown]
# -- In what years the neonatal mortality rates were above average?
#
#
# > The neonatal mortality rates were above average from the year 1990 until 2003. However, 1994 is excluded from this list. I displayed the average then displayed the neonatal mortality rate in descending order to determine which ones are above average.
#
# ![HW2_SQL_neoavg1.PNG](data:image/png;base64,...)![HW2_SQL_neoavg2.PNG](data:image/png;base64,...)

# %% [markdown]
# -- Display the sorted infant mortality rates in descending order.
#
#
# ![HW2_SQL_infantdesc1.PNG](data:image/png;base64,...)![HW2_SQL_infantdesc2.PNG](data:image/png;base64,...)![HW2_SQL_infantdesc3.PNG](data:image/png;base64,...)

# %% [markdown]
# -- Display min, max, mean, variance, and standard deviation for each mortality rate.
#
#
# > I have attached the SQL calculations below. I calculated each value for each mortality rate and separated them by their mortality rate type.
#
#
# ![HW2_SQL_under5.PNG](data:image/png;base64,...)![HW2_SQL_inf.PNG](data:image/png;base64,...)
# ![HW2_SQL_neonatal.PNG](data:image/png;base64,...)

# %% [markdown]
# -- Add a new column called Above-Five Mortality Rate and populate it with appropriate values.
#
#
# > I added the new column using the first screenshot of SQL syntax below. Then I used this website: https://data.unicef.org/topic/child-survival/child-and-youth-mortality-age-5-24/. It contains the mortality rates of children above 5. I downloaded the CSV and used the median values of mortality rates between the ages of 5 and 14 in the USA. I then imported the values with their appropriate years to fill the new column.
#
#
# ![HW2_SQL_addabove5.PNG](data:image/png;base64,...)![HW2_SQL_update5.PNG](data:image/png;base64,...)

# %% [markdown]
# -- Display the entire table again.
#
#
# > Once again used the select all
#
# ![HW2_SQL_finaldisplay.PNG](data:image/png;base64,...)![HW2_SQL_finaldisplay2.PNG](data:image/png;base64,...)
# ![HW2_SQL_finaldisplay3.PNG](data:image/png;base64,...)

# %% [markdown]
# Conclusion:
#
#
# > Please see the individual questions for their respective conclusions. There is no overall conclusion. For problem 2, the Excel section has an A and B. The SQL section has A through C. All of the SQL screenshots are included in here for problem 2. The Excel charts/graphs are inlcluded here as well. Please see the GitHub folder for the XML/JSON parts as well as the Excel csv files.
